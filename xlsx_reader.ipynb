# %% [markdown]
# ### The Fmr1 targets data

# %%
import pandas as pd
data = pd.read_excel("/home/keeganfl/Desktop/Work_Fall_2021/Fmr1 targets.xlsx", sheet_name = None)
data
# Out:
# {'Sheet1':       MOUSE  Unnamed: 1  Unnamed: 2  Unnamed: 3      FLY
#  0     MAP1A         NaN         NaN         NaN   Shank1
#  1     KMT2D         NaN         NaN         NaN    Map1a
#  2     SRRM2         NaN         NaN         NaN    Srrm2
#  3    TNRC18         NaN         NaN         NaN    Kmt2d
#  4       APC         NaN         NaN         NaN      Bsn
#  ..      ...         ...         ...         ...      ...
#  192     NaN         NaN         NaN         NaN   Zfp148
#  193     NaN         NaN         NaN         NaN    Tcf25
#  194     NaN         NaN         NaN         NaN     Xpr1
#  195     NaN         NaN         NaN         NaN  Csnk1g2
#  196     NaN         NaN         NaN         NaN    Cdkl5
#
#  [197 rows x 5 columns]}

# %%
df = data['Sheet1']

# %%
cols = ["MOUSE", "FLY"]
df = df[cols]

# %%
df
# Out:
#       MOUSE      FLY
# 0     MAP1A   Shank1
# 1     KMT2D    Map1a
# 2     SRRM2    Srrm2
# 3    TNRC18    Kmt2d
# 4       APC      Bsn
# ..      ...      ...
# 192     NaN   Zfp148
# 193     NaN    Tcf25
# 194     NaN     Xpr1
# 195     NaN  Csnk1g2
# 196     NaN    Cdkl5
#
# [197 rows x 2 columns]

# %% [markdown]
# ### The polysome profiling data.

# %%
import pandas as pd
data = pd.read_excel('/home/keeganfl/Desktop/Work_Fall_2021/papers/Papers/polysome_papers/polysome_data_dmel.xlsx', 
                     sheet_name = None)
# Out:
# /home/keeganfl/miniconda3/envs/plastid/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data.keys()
# Out:
# dict_keys(['wt_mature_oocyte.rep1', 'wt_mature_oocyte.rep2', 'wt_mature_oocyte.puromycin', 'wt activ_egg.rep1', 'wt activ_egg.rep2', 'wt activ_egg.puromycin'])

# %%
data['wt_mature_oocyte.rep1']
# Out:
#      Table S1. Polysomal Profiling Data for All mRNAs in Lysates of Mature Oocytes (Biological Replicate 1) that Pass the Significance Cutoff for Expression as Descibed in Supplemental Experimental Procedures, Related to Figure 1   \
# 0     normalized rpkm: rpkm was normalized according...
# 1     percentage (of total) abundance within each of...
# 2                                                   NaN
# 3                                                 Genes
# 4                                                 128up
# ...                                                 ...
# 6296                                               zfh1
# 6297                                                zip
# 6298                                                zpg
# 6299                                                zuc
# 6300                                             zwilch
#
#            Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                 NaN         NaN         NaN         NaN         NaN
# 1                 NaN         NaN         NaN         NaN         NaN
# 2     normalized rpkm         NaN         NaN         NaN         NaN
# 3                 RNP         40S   60S + 80S         low      medium
# 4          148.765807  120.516413  225.631925  266.693547  120.945388
# ...               ...         ...         ...         ...         ...
# 6296         0.293486    4.268077   11.309936   15.879719   12.247527
# 6297         0.384855    1.864517   27.777166   45.270577   35.152711
# 6298       134.388061  185.061628  342.442897  255.265996  134.758048
# 6299        14.712577   20.666619   52.019781   58.050813   35.107396
# 6300        14.292123   38.954863   85.403713   76.588149   43.822201
#
#       Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0            NaN         NaN        NaN        NaN         NaN         NaN
# 1            NaN         NaN        NaN        NaN         NaN         NaN
# 2            NaN  percentage        NaN        NaN         NaN         NaN
# 3           high         RNP        40S  60S + 80S         low      medium
# 4     135.921528    0.146067    0.11833   0.221539    0.261856    0.118752
# ...          ...         ...        ...        ...         ...         ...
# 6296    9.982666    0.005437   0.079066   0.209515     0.29417    0.226884
# 6297   53.929404    0.002341   0.011343   0.168982    0.275403    0.213851
# 6298  143.553741    0.112414   0.154802    0.28645    0.213528    0.112724
# 6299   36.337001    0.067833   0.095284   0.239839    0.267646    0.161864
# 6300   58.414988    0.045018   0.122702   0.269008    0.241241    0.138033
#
#      Unnamed: 12
# 0            NaN
# 1            NaN
# 2            NaN
# 3           high
# 4       0.133456
# ...          ...
# 6296    0.184928
# 6297    0.328079
# 6298    0.120081
# 6299    0.167533
# 6300    0.183998
#
# [6301 rows x 13 columns]

# %% [markdown]
# ### The ribosome profiling data

# %%
import pandas as pd
data = pd.read_excel('/home/keeganfl/Desktop/Work_Fall_2021/papers/Papers/polysome_papers/ribosome_data_dmel.xlsx', 
                     sheet_name = None)
# Out:
# /home/keeganfl/miniconda3/envs/plastid/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data.keys()
# Out:
# dict_keys(['Footprinting_noCHX_plus_withCHX', 'png_mature_oocyte_withCHX'])

# %%
data['Footprinting_noCHX_plus_withCHX']
# Out:
#      Table S2. Ribosome Footprinting Data for All mRNAs, Related to Figure 2  \
# 0     Presented are: mRNA abundance in rpkm (‘RNA’ c...
# 1     In columns labeled “-CHX” lysates were prepare...
# 2                                             Gene.Name
# 3                                                CG2224
# 4                                                 Idgf4
# ...                                                 ...
# 5840                                          Elongin-C
# 5841                                               prod
# 5842                                               uzip
# 5843                                                key
# 5844                                                Eap
#
#                     Unnamed: 1               Unnamed: 2  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2     mature oocyte RNA (-CHX)  wt activ egg RNA (-CHX)
# 3                    15.976103                 14.31656
# 4                   190.559234               189.058538
# ...                        ...                      ...
# 5840                139.925445               171.119854
# 5841                 55.987367                50.928255
# 5842                  7.831119                 7.221968
# 5843                 55.002748                60.476417
# 5844                 31.455166                32.091434
#
#                     Unnamed: 3                Unnamed: 4  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2     png activ egg RNA (-CHX)  mature oocyte RPF (-CHX)
# 3                    19.483066                 26.018798
# 4                   202.003735                411.762764
# ...                        ...                       ...
# 5840                173.180791                117.660883
# 5841                  62.95763                  56.26379
# 5842                  4.515934                 16.185026
# 5843                 83.487237                 67.616798
# 5844                 24.618204                 38.309935
#
#                    Unnamed: 5                Unnamed: 6  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2     wt activ egg RPF (-CHX)  png activ egg RPF (-CHX)
# 3                   53.507948                 26.698909
# 4                    822.6509                 62.166217
# ...                       ...                       ...
# 5840               216.880788                125.002133
# 5841               189.001968                  52.81395
# 5842                32.280582                 44.719715
# 5843               257.422741                 67.233731
# 5844                61.821064                 54.482852
#
#                    Unnamed: 7              Unnamed: 8  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2     mature oocyte TE (-CHX)  wt activ egg TE (-CHX)
# 3                    1.628607                3.737486
# 4                    2.160812                4.351303
# ...                       ...                     ...
# 5840                 0.840883                 1.26742
# 5841                 1.004937                3.711142
# 5842                 2.066758                4.469776
# 5843                 1.229335                4.256581
# 5844                 1.217922                1.926404
#
#                    Unnamed: 9               Unnamed: 10  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2     png activ egg TE (-CHX)  mature oocyte RNA (+CHX)
# 3                    1.370365                 15.443271
# 4                    0.307748                180.150159
# ...                       ...                       ...
# 5840                 0.721801                155.777084
# 5841                 0.838881                 60.715834
# 5842                 9.902651                  8.566536
# 5843                 0.805317                 52.263188
# 5844                 2.213112                 31.656376
#
#                   Unnamed: 11                Unnamed: 12  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2     wt activ egg RNA (+CHX)  png  activ egg RNA (+CHX)
# 3                   15.236967                   20.57106
# 4                  186.253418                 216.174624
# ...                       ...                        ...
# 5840               179.690394                 164.539859
# 5841                58.354695                  62.977216
# 5842                 6.376754                   4.250575
# 5843                66.069287                  80.843048
# 5844                35.288111                    27.6613
#
#                    Unnamed: 13              Unnamed: 14  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2     mature oocyte RPF (+CHX)  wt activ egg RPF (+CHX)
# 3                    26.469131                49.651379
# 4                   222.140074               799.089937
# ...                        ...                      ...
# 5840                 95.651606               249.478824
# 5841                 33.926882               175.876533
# 5842                 14.108106                43.719686
# 5843                  39.69742               264.676197
# 5844                 16.372797                72.402584
#
#                      Unnamed: 15              Unnamed: 16  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2     png  activ egg .RPF (+CHX)  mature oocyte TE (+CHX)
# 3                      27.731829                 1.713959
# 4                      63.723054                 1.233083
# ...                          ...                      ...
# 5840                  180.207368                 0.614029
# 5841                   64.784943                 0.558781
# 5842                   40.424782                 1.646886
# 5843                   73.075112                 0.759568
# 5844                   69.998045                 0.517204
#
#                  Unnamed: 17               Unnamed: 18
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2     wt activ egg TE (+CHX)  png  activ egg TE (+CHX)
# 3                   3.258613                  1.348099
# 4                   4.290337                  0.294776
# ...                      ...                       ...
# 5840                1.388382                   1.09522
# 5841                3.013923                  1.028704
# 5842                6.856104                  9.510427
# 5843                 4.00604                  0.903913
# 5844                2.051756                  2.530541
#
# [5845 rows x 19 columns]
